# %%
# import all plotting packages
# %matplotlib nbagg
import matplotlib.pyplot as plt
from matplotlib import colors, cm

# importing system packages
import os
import sys
import h5py
import time
import itertools

# importing the workhorse
import numpy as np
import pandas as pd

# tiff packages
from PIL import Image
import tifffile

# for the fitting procedures
from lmfit import *

from tiff_csv_util import *
from PAL_genStats import genStats

# %% [markdown]
# ### Load reduced data

# %%
#load_run?

# %%
runID=8
dfon, dfoff = load_run(runID, frameNum=-1, vmin=-1, vmax=1.e4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Linearity check

# %%
#genStats?

# %%
genStats(8, 1, sliceNum=30, ROI=[400, 500, 600, 800])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Creating a list of ROIs

# %%
# Each roi is [xmin, xmax, ymin, ymax]
roiList = []
roiList.append([100, 200, 600, 800])
roiList.append([400, 500, 600, 800])

# %% [markdown]
# ### Plotting multiple ROIs

# %%
#plotScan?

# %%
motorPos, onIzero, offIzero, sumOnList, sumOffList, imgOn, imgOff = plotScan(runID, roiList, scanID=1, plot=True, i0Key='pink-sum', frameNum=4)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %%
_= sumScans(runID, roiList, [1], plot=True, i0Key='pink-sum', frameNum=4)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %%
plotROIs(runID, roiList, scanIDList=[1], i0Key='pink-sum')
# Out:
# <img src="data:image/png;base64,..." width="900">
